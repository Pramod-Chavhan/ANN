# %% [markdown]
# *Problem statement* :
# <br>The following dataset consists of 1030 instances with 9 attributes and has no missing values. There are 8 input variables and 1 output variable. Seven input variables represent the amount of raw material (measured in kg/m³) and one represents Age (in Days). The target variable is Concrete Compressive Strength measured in (Mega Pascal). Build a Neural network model to predict the compressive strength.

# %%
#importing required libraries
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
#loading dataset
data = pd.read_csv("D:\\DataScience\\Class\\assignment working\\ANN\\concrete.csv")
data.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
#seperating target and input data
x=data.drop("strength",axis=1)
y=data.strength

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state =1)
x_train.shape
# Out:
# (721, 8)

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test =  scale.fit_transform(x_test)

# %%
#defining model
def design_mlp():
    # Initializing the model 
    model = Sequential()
    model.add(Dense(15,input_dim =8,activation="relu"))
    model.add(Dense(50,activation="relu"))
    model.add(Dense(7,activation="relu"))
    model.add(Dense(1,activation="relu"))
    model.compile(loss="mean_squared_error",optimizer="RMSprop",metrics=["RootMeanSquaredError"])
    return model

model = design_mlp()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 15)                135
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                800
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 357
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 1,300
# Trainable params: 1,300
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fitting model
model.fit(x=x_train,y=y_train,batch_size=1,epochs=100)
# Out:
# Epoch 1/100
# 721/721 [==============================] - 1s 2ms/step - loss: 634.0531 - root_mean_squared_error: 25.1804
# Epoch 2/100
# 721/721 [==============================] - 1s 2ms/step - loss: 207.6005 - root_mean_squared_error: 14.4083
# Epoch 3/100
# 721/721 [==============================] - 1s 2ms/step - loss: 180.0058 - root_mean_squared_error: 13.4166
# Epoch 4/100
# 721/721 [==============================] - 1s 1ms/step - loss: 175.5081 - root_mean_squared_error: 13.2479
# Epoch 5/100
# 721/721 [==============================] - 1s 1ms/step - loss: 158.0456 - root_mean_squared_error: 12.5716
# Epoch 6/100
# 721/721 [==============================] - 1s 1ms/step - loss: 147.3062 - root_mean_squared_error: 12.1370
# Epoch 7/100
# 721/721 [==============================] - 1s 2ms/step - loss: 145.2806 - root_mean_squared_error: 12.0532
# Epoch 8/100
# 721/721 [==============================] - 1s 2ms/step - loss: 139.8295 - root_mean_squared_error: 11.8250
# Epoch 9/100
# 721/721 [==============================] - 1s 1ms/step - loss: 132.5731 - root_mean_squared_error: 11.5140
# Epoch 10/100
# 721/721 [==============================] - 1s 1ms/step - loss: 125.0285 - root_mean_squared_error: 11.1816
# Epoch 11/100
# 721/721 [==============================] - 1s 2ms/step - loss: 118.5616 - root_mean_squared_error: 10.8886
# Epoch 12/100
# 721/721 [==============================] - 1s 2ms/step - loss: 110.6244 - root_mean_squared_error: 10.5178
# Epoch 13/100
# 721/721 [==============================] - 1s 1ms/step - loss: 102.3677 - root_mean_squared_error: 10.1177
# Epoch 14/100
# 721/721 [==============================] - 1s 2ms/step - loss: 97.0455 - root_mean_squared_error: 9.8512
# Epoch 15/100
# 721/721 [==============================] - 1s 1ms/step - loss: 86.3433 - root_mean_squared_error: 9.2921
# Epoch 16/100
# 721/721 [==============================] - 1s 2ms/step - loss: 78.5668 - root_mean_squared_error: 8.8638
# Epoch 17/100
# 721/721 [==============================] - 1s 2ms/step - loss: 72.9332 - root_mean_squared_error: 8.5401
# Epoch 18/100
# 721/721 [==============================] - 1s 1ms/step - loss: 64.4054 - root_mean_squared_error: 8.0253
# Epoch 19/100
# 721/721 [==============================] - 1s 2ms/step - loss: 58.4251 - root_mean_squared_error: 7.6436
# Epoch 20/100
# 721/721 [==============================] - 1s 1ms/step - loss: 54.6186 - root_mean_squared_error: 7.3904
# Epoch 21/100
# 721/721 [==============================] - 1s 1ms/step - loss: 50.7290 - root_mean_squared_error: 7.1224
# Epoch 22/100
# 721/721 [==============================] - 1s 1ms/step - loss: 47.7374 - root_mean_squared_error: 6.9092
# Epoch 23/100
# 721/721 [==============================] - 1s 2ms/step - loss: 49.9491 - root_mean_squared_error: 7.0675
# Epoch 24/100
# 721/721 [==============================] - 1s 2ms/step - loss: 45.7857 - root_mean_squared_error: 6.7665
# Epoch 25/100
# 721/721 [==============================] - 2s 2ms/step - loss: 45.7817 - root_mean_squared_error: 6.7662
# Epoch 26/100
# 721/721 [==============================] - 1s 2ms/step - loss: 45.6991 - root_mean_squared_error: 6.7601
# Epoch 27/100
# 721/721 [==============================] - 1s 2ms/step - loss: 44.3061 - root_mean_squared_error: 6.6563
# Epoch 28/100
# 721/721 [==============================] - 1s 1ms/step - loss: 42.0046 - root_mean_squared_error: 6.4811
# Epoch 29/100
# 721/721 [==============================] - 1s 1ms/step - loss: 42.9749 - root_mean_squared_error: 6.5555
# Epoch 30/100
# 721/721 [==============================] - 1s 1ms/step - loss: 42.9277 - root_mean_squared_error: 6.5519
# Epoch 31/100
# 721/721 [==============================] - 1s 2ms/step - loss: 42.2303 - root_mean_squared_error: 6.4985
# Epoch 32/100
# 721/721 [==============================] - 1s 1ms/step - loss: 40.6353 - root_mean_squared_error: 6.3746
# Epoch 33/100
# 721/721 [==============================] - 1s 2ms/step - loss: 40.1085 - root_mean_squared_error: 6.3331
# Epoch 34/100
# 721/721 [==============================] - 1s 1ms/step - loss: 39.7580 - root_mean_squared_error: 6.3054
# Epoch 35/100
# 721/721 [==============================] - 1s 2ms/step - loss: 39.5041 - root_mean_squared_error: 6.2852
# Epoch 36/100
# 721/721 [==============================] - 1s 1ms/step - loss: 38.6627 - root_mean_squared_error: 6.2179
# Epoch 37/100
# 721/721 [==============================] - 1s 1ms/step - loss: 40.0256 - root_mean_squared_error: 6.3266
# Epoch 38/100
# 721/721 [==============================] - 1s 2ms/step - loss: 38.4047 - root_mean_squared_error: 6.1972
# Epoch 39/100
# 721/721 [==============================] - 1s 2ms/step - loss: 36.6294 - root_mean_squared_error: 6.0522
# Epoch 40/100
# 721/721 [==============================] - 1s 1ms/step - loss: 38.5861 - root_mean_squared_error: 6.2118
# Epoch 41/100
# 721/721 [==============================] - 1s 1ms/step - loss: 36.4448 - root_mean_squared_error: 6.0370
# Epoch 42/100
# 721/721 [==============================] - 1s 1ms/step - loss: 35.4208 - root_mean_squared_error: 5.9515: 0s - loss: 35.2211 - root_mean_squared_e
# Epoch 43/100
# 721/721 [==============================] - 1s 1ms/step - loss: 35.2184 - root_mean_squared_error: 5.9345
# Epoch 44/100
# 721/721 [==============================] - 1s 1ms/step - loss: 35.2561 - root_mean_squared_error: 5.9377
# Epoch 45/100
# 721/721 [==============================] - 1s 2ms/step - loss: 34.3905 - root_mean_squared_error: 5.8643
# Epoch 46/100
# 721/721 [==============================] - 1s 2ms/step - loss: 35.3560 - root_mean_squared_error: 5.9461
# Epoch 47/100
# 721/721 [==============================] - 1s 1ms/step - loss: 33.6790 - root_mean_squared_error: 5.8034
# Epoch 48/100
# 721/721 [==============================] - 1s 2ms/step - loss: 34.2737 - root_mean_squared_error: 5.8544
# Epoch 49/100
# 721/721 [==============================] - ETA: 0s - loss: 32.4343 - root_mean_squared_error: 5.69 - 1s 2ms/step - loss: 33.0243 - root_mean_squared_error: 5.7467
# Epoch 50/100
# 721/721 [==============================] - 1s 2ms/step - loss: 33.2006 - root_mean_squared_error: 5.7620
# Epoch 51/100
# 721/721 [==============================] - 1s 2ms/step - loss: 33.1490 - root_mean_squared_error: 5.7575
# Epoch 52/100
# 721/721 [==============================] - 1s 1ms/step - loss: 32.3035 - root_mean_squared_error: 5.6836
# Epoch 53/100
# 721/721 [==============================] - 1s 1ms/step - loss: 32.9256 - root_mean_squared_error: 5.7381
# Epoch 54/100
# 721/721 [==============================] - 1s 1ms/step - loss: 32.7584 - root_mean_squared_error: 5.7235
# Epoch 55/100
# 721/721 [==============================] - 1s 1ms/step - loss: 33.3912 - root_mean_squared_error: 5.7785
# Epoch 56/100
# 721/721 [==============================] - 1s 1ms/step - loss: 31.9923 - root_mean_squared_error: 5.6562
# Epoch 57/100
# 721/721 [==============================] - 1s 2ms/step - loss: 31.5156 - root_mean_squared_error: 5.6139
# Epoch 58/100
# 721/721 [==============================] - 1s 2ms/step - loss: 31.1149 - root_mean_squared_error: 5.5781
# Epoch 59/100
# 721/721 [==============================] - 1s 1ms/step - loss: 31.4814 - root_mean_squared_error: 5.6108
# Epoch 60/100
# 721/721 [==============================] - 1s 2ms/step - loss: 31.5906 - root_mean_squared_error: 5.6206
# Epoch 61/100
# 721/721 [==============================] - 1s 1ms/step - loss: 30.7661 - root_mean_squared_error: 5.5467
# Epoch 62/100
# 721/721 [==============================] - 1s 1ms/step - loss: 29.9864 - root_mean_squared_error: 5.4760
# Epoch 63/100
# 721/721 [==============================] - 1s 2ms/step - loss: 30.8601 - root_mean_squared_error: 5.5552
# Epoch 64/100
# 721/721 [==============================] - 1s 2ms/step - loss: 30.6315 - root_mean_squared_error: 5.5346
# Epoch 65/100
# 721/721 [==============================] - 1s 1ms/step - loss: 29.8248 - root_mean_squared_error: 5.4612
# Epoch 66/100
# 721/721 [==============================] - 1s 2ms/step - loss: 29.2538 - root_mean_squared_error: 5.4087
# Epoch 67/100
# 721/721 [==============================] - 2s 2ms/step - loss: 28.5019 - root_mean_squared_error: 5.3387
# Epoch 68/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.6403 - root_mean_squared_error: 5.3517
# Epoch 69/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.4649 - root_mean_squared_error: 5.3352
# Epoch 70/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.6450 - root_mean_squared_error: 5.3521
# Epoch 71/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.4889 - root_mean_squared_error: 5.3375
# Epoch 72/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.0669 - root_mean_squared_error: 5.2978
# Epoch 73/100
# 721/721 [==============================] - 1s 1ms/step - loss: 27.3070 - root_mean_squared_error: 5.2256
# Epoch 74/100
# 721/721 [==============================] - 1s 2ms/step - loss: 28.7011 - root_mean_squared_error: 5.3573
# Epoch 75/100
# 721/721 [==============================] - 1s 1ms/step - loss: 28.3585 - root_mean_squared_error: 5.3253
# Epoch 76/100
# 721/721 [==============================] - 1s 2ms/step - loss: 27.2495 - root_mean_squared_error: 5.2201
# Epoch 77/100
# 721/721 [==============================] - 1s 2ms/step - loss: 26.6641 - root_mean_squared_error: 5.1637
# Epoch 78/100
# 721/721 [==============================] - 1s 1ms/step - loss: 27.7237 - root_mean_squared_error: 5.2653: 0s - loss: 29.7168 - root_mean_squ
# Epoch 79/100
# 721/721 [==============================] - 1s 1ms/step - loss: 26.3142 - root_mean_squared_error: 5.1297
# Epoch 80/100
# 721/721 [==============================] - 1s 1ms/step - loss: 26.4180 - root_mean_squared_error: 5.1398
# Epoch 81/100
# 721/721 [==============================] - 1s 1ms/step - loss: 25.5637 - root_mean_squared_error: 5.0561
# Epoch 82/100
# 721/721 [==============================] - 1s 2ms/step - loss: 26.0410 - root_mean_squared_error: 5.1030
# Epoch 83/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.9370 - root_mean_squared_error: 5.0928
# Epoch 84/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.3818 - root_mean_squared_error: 5.0380
# Epoch 85/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.4790 - root_mean_squared_error: 5.0477
# Epoch 86/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.4187 - root_mean_squared_error: 5.0417
# Epoch 87/100
# 721/721 [==============================] - 1s 2ms/step - loss: 26.3679 - root_mean_squared_error: 5.1350
# Epoch 88/100
# 721/721 [==============================] - 1s 1ms/step - loss: 25.6753 - root_mean_squared_error: 5.0671
# Epoch 89/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.2431 - root_mean_squared_error: 5.0242
# Epoch 90/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.3077 - root_mean_squared_error: 5.0307
# Epoch 91/100
# 721/721 [==============================] - 1s 2ms/step - loss: 24.1993 - root_mean_squared_error: 4.9193
# Epoch 92/100
# 721/721 [==============================] - 1s 1ms/step - loss: 24.9723 - root_mean_squared_error: 4.9972: 0s - loss: 3
# Epoch 93/100
# 721/721 [==============================] - 1s 2ms/step - loss: 25.6495 - root_mean_squared_error: 5.0645
# Epoch 94/100
# 721/721 [==============================] - 1s 2ms/step - loss: 24.4993 - root_mean_squared_error: 4.9497
# Epoch 95/100
# 721/721 [==============================] - 1s 2ms/step - loss: 24.8535 - root_mean_squared_error: 4.9853
# Epoch 96/100
# 721/721 [==============================] - 1s 2ms/step - loss: 23.4994 - root_mean_squared_error: 4.8476
# Epoch 97/100
# 721/721 [==============================] - 1s 2ms/step - loss: 23.6716 - root_mean_squared_error: 4.8653
# Epoch 98/100
# 721/721 [==============================] - 1s 2ms/step - loss: 24.2791 - root_mean_squared_error: 4.9274
# Epoch 99/100
# 721/721 [==============================] - 1s 2ms/step - loss: 23.5460 - root_mean_squared_error: 4.8524
# Epoch 100/100
# 721/721 [==============================] - 1s 2ms/step - loss: 23.6586 - root_mean_squared_error: 4.8640

# %%
model.evaluate(x_test,y_test)
# Out:
# 10/10 [==============================] - 0s 803us/step - loss: 36.7381 - root_mean_squared_error: 6.0612
# [36.738067626953125, 6.061193466186523]

# %% [markdown]
# we can see our model is giving 6.06 as error value
