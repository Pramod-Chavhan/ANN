# %% [markdown]
# Prepared by : **Ashpak Sheikh**

# %% [markdown]
# 1.	We have a dataset which contains the details of 50 startups. Build an ANN model to predict the profit of a new startup based on certain features.

# %%
#importing required libraries
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import ReLU
from tensorflow.keras.layers import Dropout

# %%
#setting seeds for re producing same results each time
np.random.seed(10)

# %%
#importing dataset
import pandas as pd
data = pd.read_csv("D:/DataScience/Class/assignment working/ANN/50_Startups (2).csv")
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
#creating dummies
data=pd.get_dummies(data,columns=['State'])
data.shape
# Out:
# (50, 7)

# %%
#seperating target and input data
x=data.drop("Profit",axis=1)
y=data.Profit

# %%
#splitting data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state =1)
x_train.shape
# Out:
# (35, 6)

# %%
#standardizing data
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_train=scale.fit_transform(x_train)
x_test =  scale.fit_transform(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
#defining model
def design_mlp():
    # Initializing the model 
    model = Sequential()
    model.add(Dense(15,input_dim =6,activation="relu"))
    model.add(Dense(7,activation="relu"))
    model.add(Dense(1,activation="linear"))
    model.compile(loss="mean_squared_error",optimizer="adam",metrics=["RootMeanSquaredError"])
    return model

model = design_mlp()

# %%
#fitting model
model.fit(x=x_train,y=y_train,batch_size=1,epochs=1000)
test_accu=model.predict(x_test)
test_accu.shape
# Out:
# Epoch 1/1000
# 35/35 [==============================] - 0s 2ms/step - loss: 15107506176.0000 - root_mean_squared_error: 122912.5938
# Epoch 2/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 15107437568.0000 - root_mean_squared_error: 122912.3203
# Epoch 3/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 15107365888.0000 - root_mean_squared_error: 122912.0234
# Epoch 4/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 15107289088.0000 - root_mean_squared_error: 122911.7109
# Epoch 5/1000
# 35/35 [==============================] - 0s 1ms/step - loss: 15107195904.0000 - root_mean_squared_error: 122911.3359
# Epoch 6/1000
# 35/35 [==============================] - 0s 914us/step - loss: 15107081216.0000 - root_mean_squared_error: 122910.8672
# Epoch 7/1000
# 35/35 [==============================] - 0s 914us/step - loss: 15106950144.0000 - root_mean_squared_error: 122910.3359
# Epoch 8/1000
# ...

# %%
model.evaluate(x_test,y_test)
# Out:
# 1/1 [==============================] - 0s 0s/step - loss: 370864672.0000 - root_mean_squared_error: 19257.8477
# [370864672.0, 19257.84765625]

# %% [markdown]
# We can see we are getting error of 19K that is beacuse we dont have enough data to train model\
# <br>Model failed to converge / reach global minima
# <br>To Get better accuracy we should gather more data as for deep networks needs more data to learn
# <br>Or try with increasing more number of epoch
